# %%
import pandas as pd

# %%
# %ls *csv
# Out:
# 001_EDSS_wheel_2CUESonSIDESmoveCORRtoMIDDLE_v27_INS_stage3_latest-19.11.14.csv

# %%
fname = '001_EDSS_wheel_2CUESonSIDESmoveCORRtoMIDDLE_v27_INS_stage3_latest-19.11.14.csv'
mysep="\n|;"
myparams = dict(sep = mysep, error_bad_lines = 0, skiprows = 0, engine='python', encoding = 'ISO-8859-1')

df = pd.read_csv(fname, **myparams)#sep = mysep, skiprows = 3, encoding = "ISO-8859-1", error_bad_lines=False)#, index_col=0)
# Out:
# Skipping line 7: Expected 17 fields in line 7, saw 42. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 11: Expected 17 fields in line 11, saw 35. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 15: Expected 17 fields in line 15, saw 35. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 19: Expected 17 fields in line 19, saw 35. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 29: Expected 17 fields in line 29, saw 38. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# Skipping line 39: Expected 17 fields in line 39, saw 35. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.
# ...

# %%
df.head(20)
# Out:
#                    ÿþDateTime          IdRFID IdLabel  \
# 0                                                      None            None
# 1       #RfidCondition      CondMod1            None
# 2                                                      None            None
# 3   43783.3951103241
# 4                                                      None            None
# 5                                                      None            None
# 6     43783.395128287  0415C48D15       Ind1
# 7                                                      None            None
# 8                                                      None            None
# 9   43783.3951316551  0415C48D15       Ind1
# 10                                                     None            None
# 11                                                     None            None
# 12  43783.3951350694  0415C48D15       Ind1
# 13                                                     None            None
# ...

# %%
df.keys()
# Out:
# Index(['ÿþDateTime', 'IdRFID', 'IdLabel',
#        'unitLabel', 'eventDuration',
#        'sense1duration', 'sense1Events',
#        'senseRFIDrecords', 'reinforce1value',
#        'reinforce1Total',
#        'reinforce1Account', 'outFuncLabel',
#        'outLabel', 'SystemMsg', 'MsgValue1',
#        'MsgValue2', 'MsgValue3'],
#       dtype='object')
